# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#restart execution of running
# !jupyter nbextension enable --py gmaps
# !jupyter nbextension list
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok
# Known nbextensions:
#   config dir: C:\Users\gshre\.jupyter\nbconfig
#     notebook section
#       jupyter-gmaps/extension enabled
#   config dir: C:\Users\gshre\Anaconda3\etc\jupyter\nbconfig
#     notebook section
#       jupyter-js-widgets/extension enabled
#       - Validating: ok
#       - Validating: ok

# %%
# Out:
#      City_ID        City  Cloudiness Country        Date  Humidity    Lat  \
# 173      173  hervey bay           0      AU  1587074074        88 -25.30
# 184      184      hwange           0      ZW  1587074092        47 -18.37
# 293      293    mercedes           0      AR  1587074074        78 -34.65
# 299      299      mocuba           0      MZ  1587074093        89 -16.84
# 316      316      namibe           0      AO  1587074071        62 -15.20
#
#         Lng  Max Temp  Wind Speed
# 173  152.85     71.01        3.36
# 184   26.50     72.21        1.59
# 293  -59.43     70.00        5.41
# 299   36.99     72.79        3.44
# 316   12.15     75.04        6.98
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# There is not hotel within the city radius of 500 meters
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# There is not hotel within the city radius of 500 meters
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': -34.6539286,
#                                         'lng': -59.43280019999999},
#                            'viewport': {'northeast': {'lat': -34.65256957010727,
#                                                       'lng': -59.43144792010728},
#                                         'southwest': {'lat': -34.65526922989272,
#                                                       'lng': -59.43414757989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'd851a51aa824fb4dbb0b1e89e434f0cdd7e74eed',
#               'name': 'Gran Hotel Mercedes',
#               'photos': [{'height': 1200,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102553908316539500331">Maria '
#                                                 'Laura Garcia</a>'],
#                           'photo_reference': 'CmRaAAAAWxsk1tNEHELI-JKMnUHTRJ57odEqoECu7ZMu3CApWw5IXOCQDAknPZf8l92fGlHKZrDim2QCk2YKouU_hNpIz-mtxo2u1VZ76lN5bKq77Qa0xtZEyMhsNrRSG31pt0YqEhBIHdVy7x_KJy3YBJZ73TUrGhQfXPSz2jqX5QaRGanuRikMm93DxA',
#                           'width': 1600}],
#               'place_id': 'ChIJhTSqUnNzvJURdRv42V5Qx5A',
#               'plus_code': {'compound_code': '8HW8+CV Mercedes, Buenos Aires '
#                                              'Province, Argentina',
#                             'global_code': '48Q28HW8+CV'},
#               'rating': 3.9,
#               'reference': 'ChIJhTSqUnNzvJURdRv42V5Qx5A',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 788,
#               'vicinity': 'Calle 16, Mercedes'},
#              {'geometry': {'location': {'lat': -34.6503621, 'lng': -59.4272097},
#                            'viewport': {'northeast': {'lat': -34.64898162010728,
#                                                       'lng': -59.42585107010727},
#                                         'southwest': {'lat': -34.65168127989273,
#                                                       'lng': -59.42855072989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'fb434dd2c11fcb5efd741b67d4caf82e6c50a124',
#               'name': 'Posada del Inti Centro',
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104628184944704927887">Rogério '
#                                                 'Tenório</a>'],
#                           'photo_reference': 'CmRaAAAAAKCAsGCul4DV0LmJnw5eXL8RYBtx7NdFmImZr7GDOrOphKoiPTQhMqHQxOjBY_93P2bgZ0p9ZFTS1d9MFSsXGa77YMBGhmbMo8il8bewjW7TjBWEPop0BJrNO_JP0Q15EhAPb8k5Cz3qQ_yViMXyPZbLGhSWvCqgH8moYPDNGZsX8t_gKEJNow',
#                           'width': 1960}],
#               'place_id': 'ChIJdXw1cnVzvJURbnoiGtOKViY',
#               'plus_code': {'compound_code': '8HXF+V4 Mercedes, Buenos Aires '
#                                              'Province, Argentina',
#                             'global_code': '48Q28HXF+V4'},
#               'rating': 3.5,
#               'reference': 'ChIJdXw1cnVzvJURbnoiGtOKViY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 45,
#               'vicinity': 'Calle 28, Mercedes'}],
#  'status': 'OK'}
#  Mercedes
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': -16.8363708, 'lng': 36.9863769},
#                            'viewport': {'northeast': {'lat': -16.83503567010728,
#                                                       'lng': 36.98777847989272},
#                                         'southwest': {'lat': -16.83773532989272,
#                                                       'lng': 36.98507882010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '5f977603ee82d4bae9e46b8a308d8ddf8af4e5f0',
#               'name': 'Sāo Cristóvão',
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111816768956583749077">orlilapaulo '
#                                                 'catela</a>'],
#                           'photo_reference': 'CmRaAAAArgeqJFwgrS4uudi8O2QA0bh1JP6u06MS1piP1RiAn0CCY6FYiRkxiWxR59MYuA8SKVgKFwqETvVf5AEhcdRtF689R7ilToicmQA7n1E1fZSnnvgpS-8E_4wnh3-_FuVrEhAjG2yk4UwvaUeC5cNS2ptKGhQw_btCN8NN2-aJguh7ZCI01ht4xA',
#                           'width': 2560}],
#               'place_id': 'ChIJO0GqUuXq0RgR3m_ZXLun3RI',
#               'plus_code': {'compound_code': '5X7P+FH Mocuba, Mozambique',
#                             'global_code': '5GMR5X7P+FH'},
#               'rating': 3.3,
#               'reference': 'ChIJO0GqUuXq0RgR3m_ZXLun3RI',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 74,
#               'vicinity': 'Ave Eduard Mondlane, Mocuba'},
#              {'geometry': {'location': {'lat': -16.8362787, 'lng': 36.9862196},
#                            'viewport': {'northeast': {'lat': -16.83496787010728,
#                                                       'lng': 36.98770657989272},
#                                         'southwest': {'lat': -16.83766752989272,
#                                                       'lng': 36.98500692010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '628027b2f0162329cc5c554f50812359c7a2ab53',
#               'name': 'Residencial Vênus',
#               'photos': [{'height': 3096,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117650753269161064656">Marco '
#                                                 'Daude</a>'],
#                           'photo_reference': 'CmRaAAAAwyKYFN7sY9aKVk7_aoGRnljcRLD9iTZZiS6muWLCN8H_GpyjWA5XLYqcnBTdr-gTe5iZadNG463U6WCfeJdFPshnvIUWStP_MPF5V_a1VhbuydaokjE72CUwt-Ge5eLaEhBxvAzxn1a0ybMEPsfCXgdqGhQEbhAQoNIx8DgICYp4QESl_vTkdw',
#                           'width': 4128}],
#               'place_id': 'ChIJBTTuUuXq0RgRN_rxjmXTN0A',
#               'plus_code': {'compound_code': '5X7P+FF Mocuba, Mozambique',
#                             'global_code': '5GMR5X7P+FF'},
#               'rating': 3.2,
#               'reference': 'ChIJBTTuUuXq0RgRN_rxjmXTN0A',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 17,
#               'vicinity': 'Ave Eduard Mondlane, Mocuba'},
#              {'geometry': {'location': {'lat': -16.8381938, 'lng': 36.9860173},
#                            'viewport': {'northeast': {'lat': -16.83683332010728,
#                                                       'lng': 36.98732847989272},
#                                         'southwest': {'lat': -16.83953297989272,
#                                                       'lng': 36.98462882010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '9694946351ea5f0d9f0529e641c87dd743955926',
#               'name': 'Pensao Cruzeiro',
#               'photos': [{'height': 1836,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116919962357974986801">Moises '
#                                                 'Mucelo</a>'],
#                           'photo_reference': 'CmRaAAAAklIll3DWCTp7fLaLRbEl0okk-BJBiBSH7M2JCo8SL9xq2WfVXOSyP1BBnjfr6hyHI5dbQkxvkqaZ32Nkg7wniRWlpxSGwjoRHvp7vxFPyBZKjR8eHrVBiTNXcjvvdZoVEhB5jt0DuwwSeNbGvcbMlZZqGhRGmAh_RSmTCj1dt2PHR88kqWPAPQ',
#                           'width': 3264}],
#               'place_id': 'ChIJMw5lKuXq0RgREmHrYMWMg8Q',
#               'plus_code': {'compound_code': '5X6P+PC Mocuba, Mozambique',
#                             'global_code': '5GMR5X6P+PC'},
#               'rating': 3,
#               'reference': 'ChIJMw5lKuXq0RgREmHrYMWMg8Q',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 197,
#               'vicinity': 'Ave Eduard Mondlane, Mocuba'},
#              {'geometry': {'location': {'lat': -16.8348623, 'lng': 36.9877428},
#                            'viewport': {'northeast': {'lat': -16.83340697010728,
#                                                       'lng': 36.98912332989272},
#                                         'southwest': {'lat': -16.83610662989272,
#                                                       'lng': 36.98642367010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '12fed773d53f91d3ed21cbadd2bb8ea886c17885',
#               'name': 'Pousada no de Deus',
#               'photos': [{'height': 2160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107224166100581420532">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAATHX8JtyXthrsBwT879a-7lcm1FsNd7xzoxtRh9QVnD-h5nAn_MtzhH8OdSo8bfqTp5-rp0eSk7KLhO5Q4UiaSqEu8IpmV1OYn6t6P0IubROj-_2F8aoVhREz77Vyz4qhEhC9te-FlKgshe1CZw0ZbgO3GhR-iy7dAqViYHA5LvlY7iQRrn0fyQ',
#                           'width': 3840}],
#               'place_id': 'ChIJxUa7cvDq0RgRFnrKUrevV1w',
#               'plus_code': {'compound_code': '5X8Q+33 Mocuba, Mozambique',
#                             'global_code': '5GMR5X8Q+33'},
#               'rating': 3.3,
#               'reference': 'ChIJxUa7cvDq0RgRFnrKUrevV1w',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 32,
#               'vicinity': 'Mocuba'},
#              {'geometry': {'location': {'lat': -16.8339484, 'lng': 36.9917071},
#                            'viewport': {'northeast': {'lat': -16.83255762010728,
#                                                       'lng': 36.99297322989272},
#                                         'southwest': {'lat': -16.83525727989272,
#                                                       'lng': 36.99027357010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'dba4a9079c90982568581a584131fcc9f4afcc1d',
#               'name': 'Complexo se Lulú',
#               'photos': [{'height': 640,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109710741851086172161">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAiVi1XF2KPajatPa7JFVuMTaFTyIfM_5DAdKlURz3DgKTCR1QKjBof0d0W8Ysq6mwL8q3B4WU00TETgSYdRx7MaT7RjDUdI7tRSoVW3wZeDrwjSR6gHtT5b3BkpDiqXFZEhC1bETJWzrOuR0RPCMe08aKGhToWGnyYwThSpQ8cBKRQBPvYwtaDg',
#                           'width': 640}],
#               'place_id': 'ChIJUZWysvDq0RgRSaCx0AL6ohY',
#               'plus_code': {'compound_code': '5X8R+CM Mocuba, Mozambique',
#                             'global_code': '5GMR5X8R+CM'},
#               'rating': 3.6,
#               'reference': 'ChIJUZWysvDq0RgRSaCx0AL6ohY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 11,
#               'vicinity': 'Mocuba'},
#              {'geometry': {'location': {'lat': -16.8343591, 'lng': 36.9914764},
#                            'viewport': {'northeast': {'lat': -16.83296307010728,
#                                                       'lng': 36.99274387989272},
#                                         'southwest': {'lat': -16.83566272989272,
#                                                       'lng': 36.99004422010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '01ee2eeec0978512de1d6071fa96121216cc97f4',
#               'name': 'Ali Moga',
#               'place_id': 'ChIJ90eKq_Dq0RgRdBb0gcyWEPM',
#               'plus_code': {'compound_code': '5X8R+7H Mocuba, Mozambique',
#                             'global_code': '5GMR5X8R+7H'},
#               'rating': 3.6,
#               'reference': 'ChIJ90eKq_Dq0RgRdBb0gcyWEPM',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 28,
#               'vicinity': 'Mocuba'},
#              {'geometry': {'location': {'lat': -16.8352109, 'lng': 36.9857258},
#                            'viewport': {'northeast': {'lat': -16.83385802010728,
#                                                       'lng': 36.98706392989271},
#                                         'southwest': {'lat': -16.83655767989272,
#                                                       'lng': 36.98436427010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '3596681f309bcad42ef8fae95137810318d178ba',
#               'name': 'Phama Lodge',
#               'photos': [{'height': 2592,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112515173849192722829">Rita '
#                                                 'Bragança</a>'],
#                           'photo_reference': 'CmRaAAAAHqMzz21nfYzzHJWiugRePZmxqTDI8sHB8D6ITU2TIDyNjkMuWHjth2p-e71HFpqckGj0jiaCeyvtmr1VJpJZWOmwAME3TojkN-d33mQTxQElcWU7-oXq6-eKmhGiWDC1EhAfN40ezgLRdWfbHFnFPDOVGhS9LFmGR6lDUAU0O5uzivzwkg0HQA',
#                           'width': 1944}],
#               'place_id': 'ChIJXxxP5e_q0RgR6X_xAvgTj1k',
#               'plus_code': {'compound_code': '5X7P+W7 Mocuba, Mozambique',
#                             'global_code': '5GMR5X7P+W7'},
#               'rating': 4.1,
#               'reference': 'ChIJXxxP5e_q0RgR6X_xAvgTj1k',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 18,
#               'vicinity': 'Rua da Mesquita, 37, Mocuba'}],
#  'status': 'OK'}
#  Mocuba
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# There is not hotel within the city radius of 500 meters
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': -17.8754094, 'lng': 36.8886082},
#                            'viewport': {'northeast': {'lat': -17.87408457010727,
#                                                       'lng': 36.88993802989273},
#                                         'southwest': {'lat': -17.87678422989272,
#                                                       'lng': 36.88723837010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '54df0263d03401fa06a8957596d8b3d5a8794565',
#               'name': 'Liduina Guest House',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 960,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110645721670284756755">Edmilson '
#                                                 'Baine</a>'],
#                           'photo_reference': 'CmRaAAAAJvuP-HYYABTtcE_PuUda9LTpZfy3UnvNbgqph_6_jRAKPKn_BwNU4nSaXWljESdDvGuvdXD-tZdjwxetIRzo_77fHz2yCdApfaNYDjpWXJL9ahRKKqWno4GsLtp_7wTeEhCs-IBFRApvC-2JPGnTz96sGhRErhu8F2gqlbe3SOO1Sj3Oj0QCeg',
#                           'width': 1280}],
#               'place_id': 'ChIJO3C4nsfz0hgRMhM7-VPZ88o',
#               'plus_code': {'compound_code': '4VFQ+RC Quelimane, Mozambique',
#                             'global_code': '5GJR4VFQ+RC'},
#               'rating': 0,
#               'reference': 'ChIJO3C4nsfz0hgRMhM7-VPZ88o',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 0,
#               'vicinity': 'Ave 7 de Setembro, Quelimane'},
#              {'geometry': {'location': {'lat': -17.8757216, 'lng': 36.8834247},
#                            'viewport': {'northeast': {'lat': -17.87438187010727,
#                                                       'lng': 36.88472732989272},
#                                         'southwest': {'lat': -17.87708152989272,
#                                                       'lng': 36.88202767010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'b4ead531df4cb5878361e6d7502d8789cc43b8f2',
#               'name': 'Milénio Hotel',
#               'photos': [{'height': 1836,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115540138791035025128">Aderito '
#                                                 'Simango</a>'],
#                           'photo_reference': 'CmRaAAAAY5af_rymZnPdTGENwotU6AsvJTM2FqoCKQwmdY4JVTztdGYr4x3Qqtzc6KUKgobsFlNJ45qwDdS8o7yPXZGU6WVw-E-XNwCMI5847GSnCGb2lGHGsJEIiRQp-nMngIS6EhDVPUO-tNcSuqJeetw74lHaGhSkvkKjuQ_KkaeNNs-UFeljajBRrA',
#                           'width': 3264}],
#               'place_id': 'ChIJedMkafHz0hgRpqFjL3RzQOI',
#               'plus_code': {'compound_code': '4VFM+P9 Quelimane, Mozambique',
#                             'global_code': '5GJR4VFM+P9'},
#               'rating': 3.8,
#               'reference': 'ChIJedMkafHz0hgRpqFjL3RzQOI',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 194,
#               'vicinity': 'Rua Zedequias Manganhela, Quelimane'},
#              {'geometry': {'location': {'lat': -17.8804543, 'lng': 36.8870337},
#                            'viewport': {'northeast': {'lat': -17.87907622010728,
#                                                       'lng': 36.88840997989272},
#                                         'southwest': {'lat': -17.88177587989273,
#                                                       'lng': 36.88571032010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'dae8fafbb8cafa063efae4528606c1a1933ae95c',
#               'name': 'Hotel Flamingo',
#               'photos': [{'height': 3648,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102943759631441127216">Helder '
#                                                 'Araujo</a>'],
#                           'photo_reference': 'CmRaAAAAs2PBoHu2Bh0Ot3ZpBflmP-goKAYdMNIFzlDX3-aSmXfWxmUd7VpYwzSe0s-IaFB5OYoJa1qcodKp12q3TwdURkt4IYYSBB4c5Ya5nv4sEGucVr6nSGFH2T-RsRN5AYN5EhDKPjS1Kg_OCjG01bupeXQnGhT5OL7Yx-_5CSsmcYmRCNjt7PjDZQ',
#                           'width': 5472}],
#               'place_id': 'ChIJRacZ_-zz0hgRRG-x8L7vl7s',
#               'plus_code': {'compound_code': '4V9P+RR Quelimane, Mozambique',
#                             'global_code': '5GJR4V9P+RR'},
#               'rating': 3.6,
#               'reference': 'ChIJRacZ_-zz0hgRRG-x8L7vl7s',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 164,
#               'vicinity': 'Ave I de Julho, Quelimane'},
#              {'geometry': {'location': {'lat': -17.8790223, 'lng': 36.8919058},
#                            'viewport': {'northeast': {'lat': -17.87754077010728,
#                                                       'lng': 36.89322622989273},
#                                         'southwest': {'lat': -17.88024042989272,
#                                                       'lng': 36.89052657010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '392b97ac2b61f3f69c866694f4fff76802a96ae1',
#               'name': 'Residencial Villa Nagardás',
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106337859390384455497">Nélio '
#                                                 'Leopoldo</a>'],
#                           'photo_reference': 'CmRaAAAAPjUY4jW6_Y3IZAwXm-thUWirQTZJ7fCdAsFMgjkeKO6BlzIgFZYX74EvpPm_C9dfqrsbSv5ndlxWw-vo8qgWG87WdPo1ZXFeX4SshEaEQV3_6tyQMJMBt34iVgZFwJSbEhDHwSi8rZFgHu05UMGVWZEoGhTVVKb1HqZH78VZbRiQ8hXhSEDCDg',
#                           'width': 1920}],
#               'place_id': 'ChIJU9LC-5Lz0hgRTcjR9SQtbzs',
#               'plus_code': {'compound_code': '4VCR+9Q Quelimane, Mozambique',
#                             'global_code': '5GJR4VCR+9Q'},
#               'rating': 4,
#               'reference': 'ChIJU9LC-5Lz0hgRTcjR9SQtbzs',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 172,
#               'vicinity': 'Quelimane'},
#              {'geometry': {'location': {'lat': -17.8778299, 'lng': 36.8838266},
#                            'viewport': {'northeast': {'lat': -17.87653267010728,
#                                                       'lng': 36.88513417989272},
#                                         'southwest': {'lat': -17.87923232989272,
#                                                       'lng': 36.88243452010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '4ca0152ebaa18290e6bee03ff5c6514a2a74b989',
#               'name': 'Elite Guest House',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1600,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101687102041837324729">Mamudo '
#                                                 'Saide</a>'],
#                           'photo_reference': 'CmRaAAAAUiEQL3KZtzMqzmUUo0LueQjBb4ziEAEQVvog_WYAq4rmglYCVdAOdfL37vAGVECKb23BCixaW4Bnd8O42Fl5gkOcojGZi8Kx3929i2cHl8ybqd54KNLHANBALXEdn6BtEhDpvz3pUeEX-u8CeyI-hYiBGhT7g6gL199yNrwt9JEJ1jMr5TyneQ',
#                           'width': 1200}],
#               'place_id': 'ChIJkf048fHz0hgRlbOYShLgON4',
#               'plus_code': {'compound_code': '4VCM+VG Quelimane, Mozambique',
#                             'global_code': '5GJR4VCM+VG'},
#               'rating': 3.8,
#               'reference': 'ChIJkf048fHz0hgRlbOYShLgON4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 49,
#               'vicinity': 'Ave I de Julho, Quelimane'},
#              {'geometry': {'location': {'lat': -17.876172, 'lng': 36.884968},
#                            'viewport': {'northeast': {'lat': -17.87495232010728,
#                                                       'lng': 36.88650722989273},
#                                         'southwest': {'lat': -17.87765197989272,
#                                                       'lng': 36.88380757010728}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '4f2e5c6287184a217230ec26d348f866bc5cc7ed',
#               'name': 'Casa de Hospedes Januário & Servicos. Lda',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 720,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110930660962846388084">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAd1f-qn-hAzAnfzOXTdWfh9Y-UO7nSY8BYnL95FrOKyPkGAyttwHJhAivLwzDZsBiLqtWjp6_CPT2z-WM1UBZAI0G6lQVirhdy0ESquYtnjTYxIU4hA9mtor-szXGCs6tEhA0KXzsUUOnRBFWk4QMHlEKGhSeoZNW3XNYaFvBrEpVwXHRA4k9Xw',
#                           'width': 960}],
#               'place_id': 'ChIJz78VMvLz0hgRRQeRbyht4a4',
#               'plus_code': {'compound_code': '4VFM+GX Quelimane, Mozambique',
#                             'global_code': '5GJR4VFM+GX'},
#               'rating': 3.3,
#               'reference': 'ChIJz78VMvLz0hgRRQeRbyht4a4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 15,
#               'vicinity': 'Ave Paulo Kamkomba, Quelimane'},
#              {'geometry': {'location': {'lat': -17.877783, 'lng': 36.8849699},
#                            'viewport': {'northeast': {'lat': -17.87637427010728,
#                                                       'lng': 36.88636572989272},
#                                         'southwest': {'lat': -17.87907392989273,
#                                                       'lng': 36.88366607010727}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'ea0c640d4224ba460409c7907a2aabd96e7b4caa',
#               'name': 'Residencial Chuabo',
#               'opening_hours': {'open_now': True},
#               'place_id': 'ChIJuwsAchnz0hgR1jbfCQpF-Pg',
#               'plus_code': {'compound_code': '4VCM+VX Quelimane, Mozambique',
#                             'global_code': '5GJR4VCM+VX'},
#               'rating': 0,
#               'reference': 'ChIJuwsAchnz0hgR1jbfCQpF-Pg',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 0,
#               'vicinity': 'Ave Josina Machel, Quelimane'}],
#  'status': 'OK'}
#  Quelimane
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': -32.9436006, 'lng': -60.6452366},
#                            'viewport': {'northeast': {'lat': -32.94232287010727,
#                                                       'lng': -60.64390372010728},
#                                         'southwest': {'lat': -32.94502252989272,
#                                                       'lng': -60.64660337989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'd84d4175fe0410b4e55d39b8db4c28b07a20fccf',
#               'name': 'Hotel Plaza Real',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107050026110072248564">Analia '
#                                                 'Sol Garcia</a>'],
#                           'photo_reference': 'CmRaAAAAEzvCu-FwSTUXiIYgFdEwRp-dvSs430kcZnZaprUrIGyZoYl-FZ33eXvhL0kOg0SR5IDCK9jE-wNDC2pd7J_UR6IEvO-U8nXJYENBXYT3HV8U6X8YfW_8BOjNCq4-O0TjEhBQfMjxZQJaOw3Wam0xhDB1GhQLo1JQmKwRjuWkPKceS3h9wxJqhg',
#                           'width': 4032}],
#               'place_id': 'ChIJKaVX3pWrt5URwbT5XZra0Ks',
#               'plus_code': {'compound_code': '3943+HW Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX3943+HW'},
#               'rating': 4.2,
#               'reference': 'ChIJKaVX3pWrt5URwbT5XZra0Ks',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2597,
#               'vicinity': 'AZT, Sta Fe 1632, Rosario'},
#              {'geometry': {'location': {'lat': -32.944548, 'lng': -60.636492},
#                            'viewport': {'northeast': {'lat': -32.94325687010728,
#                                                       'lng': -60.63517712010728},
#                                         'southwest': {'lat': -32.94595652989272,
#                                                       'lng': -60.63787677989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '31231d8b10b65f35aefe00a950608a89bd72f96c',
#               'name': 'Esplendor by Wyndham Savoy Rosario',
#               'photos': [{'height': 2368,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102875742819199630221">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAATUkuY3gz2VtZNHEUO2W5Z0UN0Nwys8hMLWw2wtsv3-aGpBommBkcP-VC2S7z9EXPkKRql7Lyo99s1AG8gwoyYY29_oDll2jDzjXFZpFdoOA7xkApx91U5LOHyi16NXvFEhB1PmJZcQbTuq2SyMdyZdkCGhRMHdLsWPwIh_PQ7-m9TQSawnhMCg',
#                           'width': 4208}],
#               'place_id': 'ChIJG45AXD2rt5URDAekHGfTSm4',
#               'plus_code': {'compound_code': '3947+5C Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX3947+5C'},
#               'rating': 4.3,
#               'reference': 'ChIJG45AXD2rt5URDAekHGfTSm4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2946,
#               'vicinity': 'San Lorenzo 1022, Rosario'},
#              {'geometry': {'location': {'lat': -32.9541676,
#                                         'lng': -60.64470379999999},
#                            'viewport': {'northeast': {'lat': -32.95284757010729,
#                                                       'lng': -60.64336222010728},
#                                         'southwest': {'lat': -32.95554722989273,
#                                                       'lng': -60.64606187989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'b57f59c09491c487bb64f4a081a39980a6fc78f6',
#               'name': '1412 Hotel Boutique de Lujo',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3096,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103022771444268013320">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAMhkMs1p_7x5GsUWJydSlWiWKoblqKKKgxj6PvnXLOWAKs0tGF16PLoDFpxvVvYXEc9-j9kHEYE4m-cuYinqRCB7xjPnQQFyeeZWp41J3uhgWzwIYA7Ahky2W4xCjJBNDEhBz6bQeQz_3qkoSdsYEtwAvGhQDj4eY2p0D20xKJX6nS0AWMra2UQ',
#                           'width': 4128}],
#               'place_id': 'ChIJIbEN6RGrt5URuEu-uossdJA',
#               'plus_code': {'compound_code': '29W4+84 Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX29W4+84'},
#               'rating': 3.9,
#               'reference': 'ChIJIbEN6RGrt5URuEu-uossdJA',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 331,
#               'vicinity': 'Zeballos 1412, BQD'},
#              {'geometry': {'location': {'lat': -32.9476866,
#                                         'lng': -60.64223759999999},
#                            'viewport': {'northeast': {'lat': -32.94627247010727,
#                                                       'lng': -60.64087302010727},
#                                         'southwest': {'lat': -32.94897212989272,
#                                                       'lng': -60.64357267989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '3062d0e6179b583bad7390990ef246b8d813684e',
#               'name': 'Hotel Rosario',
#               'photos': [{'height': 1836,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100601878647694534980">luis '
#                                                 'navarro</a>'],
#                           'photo_reference': 'CmRaAAAAwGHWUITvI7KxhQRNGJt7fp4GYtc0tt2-r3XcX2yQXxriK0lhdQD1jp3R7OArapAM8JbctMFaVrouVbp8epXITgUtKzQ-QA_PF8vYRUqQ66QQe4OO1LXwyI76NdTbilYiEhDwSyNLvykD5UkQG4xew6_9GhTwXawI7wJPBPzH8_EKDucx5GW7sw',
#                           'width': 3264}],
#               'place_id': 'ChIJk8gNGhert5URxzoVcZVFwYk',
#               'plus_code': {'compound_code': '3925+W4 Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX3925+W4'},
#               'rating': 3.9,
#               'reference': 'ChIJk8gNGhert5URxzoVcZVFwYk',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1271,
#               'vicinity': 'BAC, Ricardone 1365, Rosario'},
#              {'geometry': {'location': {'lat': -32.945164, 'lng': -60.6355746},
#                            'viewport': {'northeast': {'lat': -32.94376652010727,
#                                                       'lng': -60.63420012010727},
#                                         'southwest': {'lat': -32.94646617989272,
#                                                       'lng': -60.63689977989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '075307a226e59496a6a22fd66291465f222e9d51',
#               'name': 'Hotel Solans República',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2340,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101264331374352800451">Guillermo '
#                                                 'Andres Bertero</a>'],
#                           'photo_reference': 'CmRaAAAAqna9AdFMtIFlb446WodhYAXtzlUs5NAABGnmSmnppK2mV5mYQ6-9ZYUVswbJa_YmdJO4NKMOlkXJkiiXmeHmx2YMwE3c_t3ZZ3Woa3U9_M48-_Ie4SUHSgIJa0EaM2xCEhAizEVdVBPbJUch5mfp-PpHGhRnymfGtCdC1LqHBWHYlmEg-y-Sqg',
#                           'width': 4160}],
#               'place_id': 'ChIJC-7f3xirt5UReaS7vz0J820',
#               'plus_code': {'compound_code': '3937+WQ Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX3937+WQ'},
#               'rating': 3.9,
#               'reference': 'ChIJC-7f3xirt5UReaS7vz0J820',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1334,
#               'vicinity': 'ARE, San Lorenzo 955, Rosario'},
#              {'geometry': {'location': {'lat': -32.9458695,
#                                         'lng': -60.63937439999999},
#                            'viewport': {'northeast': {'lat': -32.94454222010728,
#                                                       'lng': -60.63808512010726},
#                                         'southwest': {'lat': -32.94724187989272,
#                                                       'lng': -60.64078477989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '3c56031bf3bbf06fd5ab4beb28d9b9f16afb03c3',
#               'name': 'Be King Hostel Rosario',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4608,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106327140415172931992">Be '
#                                                 'King Hostel</a>'],
#                           'photo_reference': 'CmRaAAAA3YkPKHYVw_ITZ7diI3k-s1DYgBISCKWK8TLiMEMiWCEkqxjcp9FspMxg7G8iTnFEoM1CAB36sNemfjMNxCAqqbHOkEmYvgF9D8hdKlM0s7Tdq1l4oQ01BoegBEJ2Si-cEhDtK78n5bPsiQb8fXR7ySmbGhSEFTwKl1s7bA40-QhTzbQWYZvPAA',
#                           'width': 3072}],
#               'place_id': 'ChIJ0wddLRirt5UR73Uy1KaRE-8',
#               'plus_code': {'compound_code': '3936+M7 Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX3936+M7'},
#               'rating': 4,
#               'reference': 'ChIJ0wddLRirt5UR73Uy1KaRE-8',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 254,
#               'vicinity': 'Mitre 778, COP'},
#              {'geometry': {'location': {'lat': -32.94334, 'lng': -60.642518},
#                            'viewport': {'northeast': {'lat': -32.94194822010728,
#                                                       'lng': -60.64115717010728},
#                                         'southwest': {'lat': -32.94464787989272,
#                                                       'lng': -60.64385682989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': 'a8625e713fb73552509ae669cce4ee9e72404411',
#               'name': 'La Casa de Pandora Hostel & Bar | Rosario',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 312,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113601332639150609704">La '
#                                                 'Casa de Pandora Hostel '
#                                                 'Rosario</a>'],
#                           'photo_reference': 'CmRaAAAAER1hTCUn7Je-MSyFUa4o-CO_y7ypSntq1BaipmEEVc-zmKyZRkSwwJ1Tc7C83sbfdYl4nUeFJP4R4sAuvPAq75qrP7qMhX1FYWXQOajDXXuzI5kHx06T8BEn0GDWelGEEhAvgQi5wJggxnaeoJFhNBxRGhSIDT1kZc9NaFL3oeMAJX4oFLE6gQ',
#                           'width': 820}],
#               'place_id': 'ChIJL3v9cD2rt5URl1VD7nAKUlw',
#               'plus_code': {'compound_code': '3944+MX Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX3944+MX'},
#               'rating': 4.4,
#               'reference': 'ChIJL3v9cD2rt5URl1VD7nAKUlw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'bar', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 237,
#               'vicinity': 'ARO, San Lorenzo 1455, Rosario'},
#              {'geometry': {'location': {'lat': -32.9449659,
#                                         'lng': -60.64228439999999},
#                            'viewport': {'northeast': {'lat': -32.94362602010728,
#                                                       'lng': -60.64087752010728},
#                                         'southwest': {'lat': -32.94632567989272,
#                                                       'lng': -60.64357717989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'c80024e1a669d98554116c0f5fb758704fc7082c',
#               'name': 'Hotel Solans Libertador',
#               'photos': [{'height': 4126,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100653602810396693879">Hotel '
#                                                 'Solans Libertador</a>'],
#                           'photo_reference': 'CmRaAAAA2v_5OfaKLD04dAbFUP9SCY-DG1qa520ujo2jeiQ38I6RPI_vWOrNeG8UwQvWvVOaRuvvDE0JO-hZL9qpgpzuqi9F8VEgjdnrDrJaxUU8F-TsiqFQeWwt17jTsCqqxagUEhAZkX7pBuAJoLF9TdC0XEbUGhTCb_Kyxex8Og4lTaOZZ70dF1WkMQ',
#                           'width': 2848}],
#               'place_id': 'ChIJT83CxRert5URQyVmTMC1RCI',
#               'plus_code': {'compound_code': '3945+23 Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX3945+23'},
#               'rating': 4.2,
#               'reference': 'ChIJT83CxRert5URQyVmTMC1RCI',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1124,
#               'vicinity': 'Corrientes 752, CTT'},
#              {'geometry': {'location': {'lat': -32.9473574, 'lng': -60.6415076},
#                            'viewport': {'northeast': {'lat': -32.94602412010728,
#                                                       'lng': -60.64006227010726},
#                                         'southwest': {'lat': -32.94872377989272,
#                                                       'lng': -60.64276192989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'd7761f9a6b44324c7daecf57285c9215f00146f9',
#               'name': 'Roberta Rosa de Fontana Suites',
#               'photos': [{'height': 4128,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114805837382454179766">Andrés '
#                                                 'Gonzalez</a>'],
#                           'photo_reference': 'CmRaAAAAylNROaAKr_iIIASu129irJZMu0eYSSu_5UatUDf0KumMadTQLwQhpTeE9qdj6kNm6GNWs_fYgpNzWb0KnfVkOqMGJyCFBj1CM35C_EmosaUx1_mCs_GFvVMhKe51V0PNEhAGM3n2hvDEMCvyi8dc6vIqGhSi_KaJh9lX0fxn-4JlrYpzBrPfWQ',
#                           'width': 3096}],
#               'place_id': 'ChIJFf-jbBert5URHY1h5jO9ax0',
#               'plus_code': {'compound_code': '3935+39 Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX3935+39'},
#               'rating': 4.4,
#               'reference': 'ChIJFf-jbBert5URHY1h5jO9ax0',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 722,
#               'vicinity': 'Entre Ríos 914, Rosario'},
#              {'geometry': {'location': {'lat': -32.953683,
#                                         'lng': -60.63570099999999},
#                            'viewport': {'northeast': {'lat': -32.95233052010728,
#                                                       'lng': -60.63436367010727},
#                                         'southwest': {'lat': -32.95503017989272,
#                                                       'lng': -60.63706332989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '68633e13d62a8ccbc59bae21f50dc1543f87cf9b',
#               'name': 'Kymani House',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1280,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113974823235690260053">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAA9Hn3atXK0KxQR8G9_pF0n2sleJO1lX6L8UxuD8Zr9yrdt83yLG2_MHC2e5RlPVBrDKkTaPH_L2qPJyzzgw1vpB5WTGF9EwoATQmH2YmNYhTqrCEovSY8zONvQm6tHIBnEhBGgv-sidliNczv3LjSXTZUGhTrSdVlkrUXALhczoIV6LN1qCpXzw',
#                           'width': 719}],
#               'place_id': 'ChIJJ1FPvwSrt5URobbSSe5r9Ms',
#               'plus_code': {'compound_code': '29W7+GP Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX29W7+GP'},
#               'rating': 4.2,
#               'reference': 'ChIJJ1FPvwSrt5URobbSSe5r9Ms',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 52,
#               'vicinity': 'Laprida 1307, Rosario'},
#              {'geometry': {'location': {'lat': -32.9506177, 'lng': -60.6449373},
#                            'viewport': {'northeast': {'lat': -32.94926367010728,
#                                                       'lng': -60.64358657010727},
#                                         'southwest': {'lat': -32.95196332989272,
#                                                       'lng': -60.64628622989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '54377395daa491bfc2c04fc0caeb68bb4ec5cb7b',
#               'name': '1495 Apart',
#               'photos': [{'height': 5312,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105025595986308096165">exequiel '
#                                                 'piedrabuena</a>'],
#                           'photo_reference': 'CmRaAAAA6Mp17tbg_VuACwPG6kCiwqHF1ZbLXrci7hVSqbJC_vHtTX4Xt_eJTO8JMLam-16RC2JdI7I06_hVBy6oOz4T2c0ttUCfiH_6scGPlnaMYtk-o_TjLJm0R9nYMltg39aIEhDHjoBd2KhpjBp-qAfYhGfVGhQbHZD9IvLW0KJl342NUIZNW6LAWQ',
#                           'width': 2988}],
#               'place_id': 'ChIJS1xrTxGrt5URiMCsfehEBOA',
#               'plus_code': {'compound_code': '29X4+Q2 Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX29X4+Q2'},
#               'rating': 4,
#               'reference': 'ChIJS1xrTxGrt5URiMCsfehEBOA',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 459,
#               'vicinity': 'Mendoza 1495, Rosario'},
#              {'geometry': {'location': {'lat': -32.9509002, 'lng': -60.6358123},
#                            'viewport': {'northeast': {'lat': -32.94950632010728,
#                                                       'lng': -60.63444017010728},
#                                         'southwest': {'lat': -32.95220597989272,
#                                                       'lng': -60.63713982989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'c1742b13683bfc4b83bac13ced0d4c8ec2937448',
#               'name': 'Nuevo City',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 585,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111371373081081902641">Yamila '
#                                                 'Giglio</a>'],
#                           'photo_reference': 'CmRaAAAA2mRjvlcmPZBBjFXKpUNE48HQNfXcLfUZIA2Mfbmx7n1g9IgP7_Njuuz1z4CO31Ig3G4b8tsSjYSzOpIkdxXdr_jYMkNLZUsBy-jMPB8YqMA2RCWZBgN6fB6gMZbrVAC9EhCjsepjDrAnKY91En82yYy9GhT01-G3NmHd1HeybM6Txh7X0l1Znw',
#                           'width': 1040}],
# ...
#                                                       'lng': -60.63897272010728},
#                                         'southwest': {'lat': -32.94485842989272,
#                                                       'lng': -60.64167237989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '3f513564d7ac9512f074f8da15c76b01a53c168b',
#               'name': 'High Hostel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 959,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104062898743342621424">A '
#                                                 'Google User</a>'],
#                           'photo_reference': 'CmRaAAAAbTo2J-qqr2qwT0I-QMC2n4C-N2tKSfwk0s3uzprP1FDgB3Ng2ZKJ-MRPyWha0vKNnnIKFheiB14fq5kVSRuMQde03rRC6PgDuclYpGSfD1U3KjJBhdpwp7MXDt4tGT59EhDW56I4b-AWKgGdBYiHtQdbGhTng0J8H6khqhNWDqoHU5lbT1WG0w',
#                           'width': 960}],
#               'place_id': 'ChIJ8dRsVD2rt5URaVorAYyAVDk',
#               'plus_code': {'compound_code': '3945+HV Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX3945+HV'},
#               'rating': 4.1,
#               'reference': 'ChIJ8dRsVD2rt5URaVorAYyAVDk',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 150,
#               'vicinity': 'CRJ, Entre Ríos 583 1A, Rosario'},
#              {'geometry': {'location': {'lat': -32.9525039,
#                                         'lng': -60.64180979999999},
#                            'viewport': {'northeast': {'lat': -32.95110772010727,
#                                                       'lng': -60.64044952010727},
#                                         'southwest': {'lat': -32.95380737989272,
#                                                       'lng': -60.64314917989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '4d2f70ba3d81384eeba4aee9bf67ef9cfb0975cc',
#               'name': 'Hoteles Euskadi SRL',
#               'photos': [{'height': 4128,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109920631198946250714">mirta '
#                                                 'serrano</a>'],
#                           'photo_reference': 'CmRaAAAAM7guDgaJyZHrDqSK7TFG9PEQErr2gzo6OuzxPatNGjZ0z-YqLbhrnU8OjdciU-CgltouGm8tdi_qDdVwTVj5nYf0aacQe7kQmx6YO1ZEfePLPJOMEATheruZ-POE-uJZEhBYkYQBAkm5UWU1ZL1j0qqyGhSR47GOwEUUWwM_ZVb_aXC5q4AQOQ',
#                           'width': 3096}],
#               'place_id': 'ChIJe8TVQhCrt5URrwlnOXGTmqk',
#               'plus_code': {'compound_code': '29W5+X7 Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX29W5+X7'},
#               'rating': 3.8,
#               'reference': 'ChIJe8TVQhCrt5URrwlnOXGTmqk',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 280,
#               'vicinity': 'Rosario'},
#              {'geometry': {'location': {'lat': -32.9559898, 'lng': -60.6356888},
#                            'viewport': {'northeast': {'lat': -32.95460387010727,
#                                                       'lng': -60.63433087010728},
#                                         'southwest': {'lat': -32.95730352989271,
#                                                       'lng': -60.63703052989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '213cba247a32df97f161e15d2573864bbe476b85',
#               'name': 'Hostel Foster Rosario',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1365,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113957817405587538617">Hostel '
#                                                 'Foster Rosario</a>'],
#                           'photo_reference': 'CmRaAAAA03jmQRSJXBAom_z45ANvvxyE-esLYugRCBEZ1fbysHBupUUnDj3ZiztgE18-j7srv1L3Y7UIdUfILlKjl6SouVdvjsIPTyca1G0_LvGAjBogTqW2LhaCjDThUxngmIW7EhBOXa3zFhci3HAoV125lUBuGhRN6N1r2JqFDqoOHQmc-4PoXR8UMw',
#                           'width': 2048}],
#               'place_id': 'ChIJU8IHaASrt5URGS9fmx5lgpA',
#               'plus_code': {'compound_code': '29V7+JP Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX29V7+JP'},
#               'rating': 3.5,
#               'reference': 'ChIJU8IHaASrt5URGS9fmx5lgpA',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 120,
#               'vicinity': 'S2000BPO E, Zeballos 759, Rosario'},
#              {'geometry': {'location': {'lat': -32.9471718, 'lng': -60.6343851},
#                            'viewport': {'northeast': {'lat': -32.94589127010727,
#                                                       'lng': -60.63278697010728},
#                                         'southwest': {'lat': -32.94859092989272,
#                                                       'lng': -60.63548662989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '22cc2af7b6845b9f677bc9fc3dac120b0eff06a4',
#               'name': '83 ROSARIO HOSTEL',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 801,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114596295926959857797">83 '
#                                                 'Rosario Hostel</a>'],
#                           'photo_reference': 'CmRaAAAAHXyf6TDlwmJzQRJCy1PmQwUQyDHwpbdA7WLRt_b0ZkIOLQ-QrEz7No9LesMhP-2iWInthm-D_JrqNxM101w21z09XUjnHkOWPXo_xSrhpj1M1opmsvoYE8FTsU7VKRXAEhDpRcE_HjdDl0vxsTgmv-wRGhQHZtTWCNnPxa88qN4OwEdSD3QjCg',
#                           'width': 1200}],
#               'place_id': 'ChIJY0BtVRmrt5URsjtsJgbkNjY',
#               'plus_code': {'compound_code': '3938+46 Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX3938+46'},
#               'rating': 3.9,
#               'reference': 'ChIJY0BtVRmrt5URsjtsJgbkNjY',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 130,
#               'vicinity': 'Córdoba 824, AWJ'},
#              {'geometry': {'location': {'lat': -32.9508921, 'lng': -60.6357203},
#                            'viewport': {'northeast': {'lat': -32.94950897010727,
#                                                       'lng': -60.63436122010727},
#                                         'southwest': {'lat': -32.95220862989272,
#                                                       'lng': -60.63706087989272}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'bb8f9e1fe7d20dca6045b3fda110425db822c469',
#               'name': 'Hotel Nuevo City',
#               'photos': [{'height': 1920,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100306629159343090637">Hernán '
#                                                 'Louzán</a>'],
#                           'photo_reference': 'CmRaAAAAmiWEQSGW3NsLCUMMyXiFO7dAKGDOf2S_swRMaLZ8rr4Rw81xwGvzM7A82TXZIp82RZGUn98jJVBc-8S8Yg45BfSaC2OoohzWl6ekw32JT3XAV-JKScZU8NSI7wZg7Ei7EhBb6tzcon3iOuwspWkuAYOuGhTlFZHrGbK2HSPWeAZmqQrphq87iQ',
#                           'width': 1080}],
#               'place_id': 'ChIJmfAWbRurt5URBDt8nx2jcHU',
#               'plus_code': {'compound_code': '29X7+JP Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX29X7+JP'},
#               'rating': 1,
#               'reference': 'ChIJmfAWbRurt5URBDt8nx2jcHU',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'San Juan 865, BDK'},
#              {'geometry': {'location': {'lat': -32.9561067, 'lng': -60.6377524},
#                            'viewport': {'northeast': {'lat': -32.95476217010729,
#                                                       'lng': -60.63637447010728},
#                                         'southwest': {'lat': -32.95746182989273,
#                                                       'lng': -60.63907412989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '503722bd4d241be9cc78ee762593301cab3628ed',
#               'name': 'Hostel Marino',
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114758920841845411229">Hostel '
#                                                 'Marino Rosario</a>'],
#                           'photo_reference': 'CmRaAAAAvnqcD7wMY8guif8VDRtk9Tk25NY3rwzkm2mX8_jL3RhbjWnDhFcB3lLuE3_mnzyHcf8s-ECKfYX6gGV-M-o_ipKX-8Wxni2ABIVPiSj9tAdnQ4qo7dp0i92h7IrkTBpaEhDZJrjJbmkmF3ewKvwZk9fNGhR4k50YNFKFafTUv8ttiBGNXUZHbA',
#                           'width': 2048}],
#               'place_id': 'ChIJfW92qQWrt5URf44UsCxIhFU',
#               'plus_code': {'compound_code': '29V6+HV Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX29V6+HV'},
#               'rating': 3.6,
#               'reference': 'ChIJfW92qQWrt5URf44UsCxIhFU',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 28,
#               'vicinity': 'CGV, Maipú 1542, Rosario'},
#              {'geometry': {'location': {'lat': -32.94567, 'lng': -60.63504},
#                            'viewport': {'northeast': {'lat': -32.94433792010728,
#                                                       'lng': -60.63360582010727},
#                                         'southwest': {'lat': -32.94703757989272,
#                                                       'lng': -60.63630547989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '6f957b4a86a363eb9c7ddf68e7394f1ab4c3dd69',
#               'name': 'Freedom Hostel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4608,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106158962761913821644">emilio '
#                                                 'alejandro luna heredia</a>'],
#                           'photo_reference': 'CmRaAAAAaLbolyd0HRJ7cNEgATM6YbgdLhXnvpv5dRrwYtJzix9BmeTbyl-sKluU2ouvbWZxRVGyNfU4BOGFSjCDJeoQBvukkrRR-draGe4OfDmtm6GJ9G0ydszuwPjFE-UnEueXEhBszwFVU6Hg_-XBOAw5U0AIGhSlQwJvDP4jYzYRkeLV8oTt9Np2Mg',
#                           'width': 3456}],
#               'place_id': 'ChIJUd2AMBmrt5URu47r83bIIc8',
#               'plus_code': {'compound_code': '3937+PX Rosario, Santa Fe '
#                                              'Province, Argentina',
#                             'global_code': '47VX3937+PX'},
#               'rating': 3.7,
#               'reference': 'ChIJUd2AMBmrt5URu47r83bIIc8',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 214,
#               'vicinity': 'Maipú 646, CGD'}],
#  'status': 'OK'}
#  Rosario
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': -31.3865244, 'lng': -57.9645367},
#                            'viewport': {'northeast': {'lat': -31.38517107010728,
#                                                       'lng': -57.96318647010727},
#                                         'southwest': {'lat': -31.38787072989272,
#                                                       'lng': -57.96588612989271}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '04816d6e155deb9cc787b7f25f039795efc94927',
#               'name': 'Hotel Español Salto',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 2322,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110743541391553844313">Gui '
#                                                 'velez</a>'],
#                           'photo_reference': 'CmRaAAAAxD0BY2ztpejDV6slkgvKy4yg6KXIx119FlfH_q0ge2_x_SewNtuzBfPbXcsp_RwYRZHlrxEOOGXuQbVM325Sml9RGIZ71bJRJBr8AhT5Yzj-2iHdmpzF8BkDL6RiLPx1EhACi51QCC24Y-KkkQTQBLY0GhRTQNV_qXlWGGcCAaZHXpR-ivQGPw',
#                           'width': 4128}],
#               'place_id': 'ChIJTYzvp9XcrZURD8ajo421uJQ',
#               'plus_code': {'compound_code': 'J27P+95 Salto, Salto Department, '
#                                              'Uruguay',
#                             'global_code': '48W4J27P+95'},
#               'rating': 4.2,
#               'reference': 'ChIJTYzvp9XcrZURD8ajo421uJQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 338,
#               'vicinity': 'Brasil 826, Salto'},
#              {'geometry': {'location': {'lat': -31.3861425, 'lng': -57.9683553},
#                            'viewport': {'northeast': {'lat': -31.38476942010728,
#                                                       'lng': -57.96700032010728},
#                                         'southwest': {'lat': -31.38746907989272,
#                                                       'lng': -57.96969997989273}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '636bb607f883ea98a93a2fc71933e6643eb4667e',
#               'name': 'Hotel Tia',
#               'photos': [{'height': 2448,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107519685013771660297">Jamil '
#                                                 'Murad</a>'],
#                           'photo_reference': 'CmRaAAAAc7oiPvEhKI6hDQEex655aeRMW6Fv6lfRAQMaQb3J87cPey5EafejhP3iKOPifNBUEUyhdQz62FlFG4Xbza0pM1PHPSOYQqOik4JktJJSN1pyyrm1LUV4BzVmAGG35omCEhAzssyfnyBIJ5KD7iRXpbC2GhQPC9PyMGuWE7I0HAPDwhJvWa8UAQ',
#                           'width': 3264}],
#               'place_id': 'ChIJZV8bRtPCrZURjEG03J_zMTA',
#               'plus_code': {'compound_code': 'J27J+GM Salto, Salto Department, '
#                                              'Uruguay',
#                             'global_code': '48W4J27J+GM'},
#               'rating': 3.5,
#               'reference': 'ChIJZV8bRtPCrZURjEG03J_zMTA',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 211,
#               'vicinity': 'Brasil 566, Salto'}],
#  'status': 'OK'}
#  Salto
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# There is not hotel within the city radius of 500 meters
# generating heatmap plots hotels
# generation complete

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>}
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ee87170f672a> in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# NameError: name 'narrowed_city_df' is not defined

# %%
# Add marker layer ontop of heat map

from city_lib import (Find_Ideal_Cities, Load_City_Data)
from vacations_lib import Find_Motels_For_Cities
from vacationplots_lib import heatmap_plot

cities_df = Load_City_Data()
ideal_cities = Find_Ideal_Cities(cities_df)
hotels = Find_Motels_For_Cities(ideal_cities)
heatmap_plot(hotels)

# Display Map
# Out:
#      City_ID        City  Cloudiness Country        Date  Humidity    Lat  \
# 173      173  hervey bay           0      AU  1587074074        88 -25.30
# 184      184      hwange           0      ZW  1587074092        47 -18.37
# 293      293    mercedes           0      AR  1587074074        78 -34.65
# 299      299      mocuba           0      MZ  1587074093        89 -16.84
# 316      316      namibe           0      AO  1587074071        62 -15.20
#
#         Lng  Max Temp  Wind Speed
# 173  152.85     71.01        3.36
# 184   26.50     72.21        1.59
# 293  -59.43     70.00        5.41
# 299   36.99     72.79        3.44
# 316   12.15     75.04        6.98
# Finding hotel for hervey bay
# There is not hotel within the city radius of 500 meters
# Finding hotel for hwange
# There is not hotel within the city radius of 500 meters
# Finding hotel for mercedes
# Finding hotel for mocuba
# Finding hotel for namibe
# There is not hotel within the city radius of 500 meters
# Finding hotel for quelimane
# Finding hotel for rosario
# Finding hotel for salto
# Finding hotel for san matias
# There is not hotel within the city radius of 500 meters
# generating heatmap plots hotels
# generation complete
